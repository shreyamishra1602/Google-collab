# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyamishra1602/Google-collab/blob/main/5jan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word="biswajit"
print(word[0])
##from front
# Out:
# b

# %%
word="biswajit"
print(word[-2])
#from back
# Out:
# i

# %%
word="biswajit"
print(word[0:5])
#slices word from front
# Out:
# biswa

# %%
word="biswajit"
print(len(word))
#prints number of element
# Out:
# 8

# %%
word="biswajit"
word=word.upper()
print(word)
# Out:
# BISWAJIT

# %%
word="BISWAJIT"
word=word.lower()
print(word)
# Out:
# biswajit

# %%
word="biswajit".title()
print(word)
# Out:
# Biswajit

# %%
data="biswajit"
data.strip()
# Out:
# 'biswajit'

# %%
word="biswajit is cooking"
print(word.replace("cooking","dancing"))
# Out:
# biswajit is dancing

# %%
email="happy@gmail.com "
print("@" in email)
# Out:
# True

# %%
text="i am blessed"
text=text.split()
print(text)
# Out:
# ['i', 'am', 'blessed']

# %%
first= "I "
Second="am"
third= "very"
fourth= "lucky"
print (first+" "+Second+" "+ third+" "+ fourth)
# Out:
# I  am very lucky

# %%
name =(input(" enter your name\n"))
age= int(input(" enter your age\n"))
print ( f"My name is {name} and age is {age} ")
# Out:
#  enter your name
# Bisu
#  enter your age
# 22
# My name is Bisu and age is 22

# %%
story="i am learning python "
print(story.count("a"))
# Out:
# 2

# %%
story="i am learning python "
story.startswith("i")
# Out:
# True

# %%
story="i am learning python"
story.endswith("python")
# Out:
# True
