# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyamishra1602/Google-collab/blob/main/2jan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
vegetables=["potatoes","onions","chilli"]
print(vegetables[1])
vegetables.append("brinjal")
print(vegetables)
# Out:
# onions
# ['potatoes', 'onions', 'chilli', 'brinjal']

# %%
students= ["alka","ansh","bisu"]
students.append ("shreya")
students.append ("happy")
print(students)
students.sort()
print(students)
# Out:
# ['alka', 'ansh', 'bisu', 'shreya', 'happy']
# ['alka', 'ansh', 'bisu', 'happy', 'shreya']

# %%
student={
    "name":"bisu",
    "age":22,
    "course":"bca"
}
print(student["course"])
student.keys()
# Out:
# bca
# dict_keys(['name', 'age', 'course'])

# %%
numbers={1,3,6,6,4,6,2,5}
print(numbers)
# Out:
# {1, 2, 3, 4, 5, 6}
