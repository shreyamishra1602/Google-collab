# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyamishra1602/Google-collab/blob/main/Math_in_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a=np.array([1,2,3,4])
b=np.array([6,7,8,9])
print(a+b)
# Out:
# [ 7  9 11 13]

# %%
x=np.array([
    [1,2],
    [3,4],
    [5,6]
])
print(np.array([1,2])*np.array([3,4])*np.array([5,6]))
# Out:
# [15 48]

# %%
np.dot([15,2],[20,4])
# Out:
# np.int64(308)

# %%
import random
outcomes=["Spam","Not Spam"]
print(random.choice(outcomes))
# Out:
# Not Spam

# %%
import numpy as np
scores=[60,70,80,90,100]
print(np.mean(scores))
# Out:
# 80.0

# %%
w=10
Ir=0.2
for i in range(10):
  w=w-Ir*2*w
  print(w)
# Out:
# 6.0
# 3.5999999999999996
# 2.1599999999999997
# 1.2959999999999998
# 0.7775999999999998
# 0.46655999999999986
# 0.2799359999999999
# 0.16796159999999993
# 0.10077695999999996
# 0.06046617599999997
